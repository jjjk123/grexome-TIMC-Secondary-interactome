# %%
import pandas as pd

import collections

import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/kubicaj/python_venvs/pyEnv_PPI/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
def plot_neighbourhood(node, G, candidates, labels=False):
    # plot the neighbourhood of the top node ENSG00000101773
    sub_G = G.subgraph([n for n in G.neighbors(node)])
    candidates_in_neighbourhood = [x for x in [n for n in sub_G.nodes()] if x in candidates]

    sub_G = nx.Graph(sub_G) # unfreeze the graph
    sub_G.remove_edges_from(nx.selfloop_edges(sub_G)) # removing self-loops

    color_map = ['orangered' if node in candidates_in_neighbourhood else 'lightblue' for node in sub_G]
    pos=nx.spring_layout(sub_G)

    plt.figure(figsize=(7, 6))
    ax = plt.gca()
    ax.set_title(f"Neighbourhood of {node}")
    nx.draw_networkx(sub_G, pos=pos, with_labels=False, node_size=100, alpha=0.9, ax=ax, node_color=color_map)

    if labels:
        # plot candidates labels
        labels = {}
        for node in sub_G.nodes():
            if node in candidates_in_neighbourhood:
                labels[node] = node

        pos_higher = {}
        for k, v in pos.items():
            if(v[1]>0):
                pos_higher[k] = (v[0]-0.1, v[1]+0.1)
            else:
                pos_higher[k] = (v[0]-0.1, v[1]-0.1)
        nx.draw_networkx_labels(sub_G, pos=pos_higher, labels=labels, font_size=10, font_color='tomato')
    
    _ = ax.axis('off')

# %%
interactome_df = pd.read_csv('./data/Interactome_human.tsv', sep='\t', header=None)
candidates = pd.read_pickle("./data/candidateGenesList_NOA.p")

G = nx.from_pandas_edgelist(interactome_df, 0, 1, edge_attr=True)
nonCandidates = [n for n in list(G.nodes) if n not in candidates]

# %% [markdown]
# ### Analyze interactome

# %%
# number of proteins
len(G.nodes())
# Out:
# 14465

# %%
# number of interactions
G.number_of_edges()
# Out:
# 92064

# %%
# degree histogram
degrees = sorted([d for n, d in G.degree()])
deg, cnt = zip(*collections.Counter(degrees).items())

plt.bar(deg, cnt)
plt.xlabel("degree")
plt.ylabel("number of nodes")
# Out:
# Text(0, 0.5, 'number of nodes')

# %%
# average degree
sum([d for _, d in G.degree()]) / G.number_of_nodes()
# Out:
# 12.7292084341514

# %% [markdown]
# ### Count candidate genes for each node neighbourhood

# %%
# count candidate genes for each node
d = {}
d2 = {}
for node in G.nodes():
    sub_G = G.subgraph([n for n in G.neighbors(node)])
    candidates_in_neighbourhood = [x for x in [n for n in sub_G.nodes()] if x in candidates]
    candidates_in_neighbourhood_cnt = len(candidates_in_neighbourhood)
    isCandidate = True if node in candidates else False

    d[node] = candidates_in_neighbourhood_cnt
    d2[node] = [candidates_in_neighbourhood_cnt, isCandidate]

# %%
s = pd.Series(d, name='# candidates in neighbourhood')
s.index.name = 'Gene'
s.reset_index()
s.sort_values(ascending=False)
# Out:
# Gene
# ENSG00000073584    2
# ENSG00000135346    2
# ENSG00000139197    2
# ENSG00000097007    2
# ENSG00000107130    2
#                   ..
# ENSG00000117054    0
# ENSG00000136878    0
# ENSG00000172046    0
# ENSG00000196177    0
# ENSG00000137767    0
# Name: # candidates in neighbourhood, Length: 14465, dtype: int64

# %%
s2 = pd.Series(d2, name='# candidates in neighbourhood')
s2.index.name = 'Gene'
s2.reset_index()
s2.sort_values(ascending=False).head(20)
# Out:
# Gene
# ENSG00000107130    [2, False]
# ENSG00000119772    [2, False]
# ENSG00000117899    [2, False]
# ENSG00000139197    [2, False]
# ENSG00000130638    [2, False]
# ENSG00000160293    [2, False]
# ENSG00000132522    [2, False]
# ENSG00000197299    [2, False]
# ENSG00000175455    [2, False]
# ENSG00000065135    [2, False]
# ENSG00000166037    [2, False]
# ENSG00000109685    [2, False]
# ENSG00000140961    [2, False]
# ENSG00000097007    [2, False]
# ENSG00000135346    [2, False]
# ENSG00000079277    [2, False]
# ENSG00000073584    [2, False]
# ENSG00000088808    [2, False]
# ENSG00000142182     [1, True]
# ENSG00000149311     [1, True]
# Name: # candidates in neighbourhood, dtype: object

# %%
ax = s.plot.hist(bins=len(set(s.values)), logy=True)
ax.set_xlabel("# candidates in neighbourhood")
ax.set_ylabel("number of nodes")
# Out:
# Text(0, 0.5, 'number of nodes')

# %%
plot_neighbourhood("ENSG00000107130", G, candidates, labels=False)

# %% [markdown]
# > Information about **ENSG00000158104:**
#
# Gene
#
# Protein

# %%
# relation between the number of candidate genes vs degree
d = {}
for node in G.nodes():
    sub_G = G.subgraph([n for n in G.neighbors(node)])
    candidates_in_neighbourhood = [x for x in [n for n in sub_G.nodes()] if x in candidates]
    candidates_in_neighbourhood_cnt = len(candidates_in_neighbourhood)
    d[node] = [candidates_in_neighbourhood_cnt, G.degree(node)]

df = pd.DataFrame.from_dict(d, orient='index', columns=['# candidates in neighbourhood', 'degree'])

# %%
df.plot.scatter(x='degree', y='# candidates in neighbourhood')
# Out:
# <Axes: xlabel='degree', ylabel='# candidates in neighbourhood'>

# %%
# fraction of candidates that are present in interactome
len([candidate for candidate in candidates if candidate in G.nodes()]) / len(candidates)

# ~50% means that the second half of candidate genes has been filtered out during the building of interactome (e.g. because they form hubs >120 connections)
# Out:
# 0.7407407407407407

# %%
# average degree of infertility candidate genes
d = {}

for node in G.nodes():
    if node in candidates:
        d[node] = G.degree(node)

sum([deg for n, deg in d.items()]) / len(d.keys())
# Out:
# 15.65

# %%
# subgraph of candidate genes
candidates_sub_G = G.subgraph([n for n in G.nodes() if n in candidates])

candidates_sub_G = nx.Graph(candidates_sub_G) # unfreeze the graph
candidates_sub_G.remove_edges_from(nx.selfloop_edges(candidates_sub_G)) # removing self-loops

plt.figure(figsize=(7, 6))
ax = plt.gca()
ax.set_title(f"Subgraph of NOA candidate genes")
# nx.draw_networkx(candidates_sub_G, with_labels=False, node_size=100, alpha=0.9, ax=ax)
nx.draw_circular(candidates_sub_G, with_labels=True, node_size=100, alpha=0.7, ax=ax, font_size=5)
_ = ax.axis('off')

# %%
# number of nodes and edges in subgraph of candidate genes
candidates_sub_G = G.subgraph([n for n in G.nodes() if n in candidates])
candidates_sub_G.number_of_nodes(), candidates_sub_G.number_of_edges()
# Out:
# (40, 6)

# %% [markdown]
# ### Score 1: Count candidate genes for each node and divide by node degree

# %%
# count candidate genes for each node and divide by node degree
d = {}
d2 = {}
for node in G.nodes():
    sub_G = G.subgraph([n for n in G.neighbors(node)])
    candidates_in_neighbourhood = [x for x in [n for n in sub_G.nodes()] if x in candidates]
    candidates_in_neighbourhood_cnt = len(candidates_in_neighbourhood)
    isCandidate = True if node in candidates else False
    score = candidates_in_neighbourhood_cnt / G.degree(node)
    
    d[node] = score
    d2[node] = [score, isCandidate, G.degree(node), candidates_in_neighbourhood_cnt]

# %%
s = pd.Series(d, name='Score 1')
s.index.name = 'Gene'
s.reset_index()
s.sort_values(ascending=False)
# Out:
# Gene
# ENSG00000118849    1.0
# ENSG00000213398    1.0
# ENSG00000197885    1.0
# ENSG00000182308    1.0
# ENSG00000183324    1.0
#                   ...
# ENSG00000117054    0.0
# ENSG00000136878    0.0
# ENSG00000172046    0.0
# ENSG00000196177    0.0
# ENSG00000137767    0.0
# Name: Score 1, Length: 14465, dtype: float64

# %%
s2 = pd.Series(d2, name='Score 1')
s2.index.name = 'Gene'
s2.reset_index()
s2.sort_values(ascending=False)
# Out:
# Gene
# ENSG00000213398    [1.0, False, 1, 1]
# ENSG00000183324    [1.0, False, 1, 1]
# ENSG00000182308    [1.0, False, 1, 1]
# ENSG00000197885    [1.0, False, 1, 1]
# ENSG00000118849    [1.0, False, 1, 1]
#                           ...
# ENSG00000187775    [0.0, False, 1, 0]
# ENSG00000240204    [0.0, False, 1, 0]
# ENSG00000174946    [0.0, False, 1, 0]
# ENSG00000156486    [0.0, False, 1, 0]
# ENSG00000102935    [0.0, False, 1, 0]
# Name: Score 1, Length: 14465, dtype: object

# %% [markdown]
# > Information about **ENSG00000205922:**
#
# Gene ONECUT3
#
# Protein O60422 *One cut domain family member 3* (**Transcriptional activator for HNF3B** -- early development; its expression emerges in the primitive streak and node at embryonic day (E) 6.5, and in the mesoderm and definitive endoderm at E7.5. and **TTR** (e.g. transports thyroid hormones in the plasma and cerebrospinal fluid))

# %%
ax = s.plot.hist(bins=len(set(s.values)), logy=True)
# ax = s[s>0].plot.hist(bins=len(set(s.values)))
ax.set_xlabel("# candidates in neighbourhood / node degree")
ax.set_ylabel("number of nodes")
# Out:
# Text(0, 0.5, 'number of nodes')

# %% [markdown]
# ### Score 2: Harmonic centrality

# %%
res_hc = nx.harmonic_centrality(G, nbunch=nonCandidates, sources=candidates)

# %%
res_hc_sorted = dict(sorted(res_hc.items(), key=lambda v: v[1], reverse=True))

# %%
res_hc_sorted
# Out:
# {'ENSG00000170365': 15.16666666666667,
#  'ENSG00000097007': 14.783333333333339,
#  'ENSG00000099956': 14.666666666666671,
#  'ENSG00000163513': 14.66666666666667,
#  'ENSG00000170312': 14.500000000000005,
#  'ENSG00000066427': 14.41666666666667,
#  'ENSG00000117475': 14.366666666666669,
#  'ENSG00000044115': 14.33333333333334,
#  'ENSG00000112062': 14.333333333333337,
#  'ENSG00000008735': 14.333333333333337,
#  'ENSG00000185811': 14.333333333333336,
#  'ENSG00000120693': 14.333333333333336,
#  'ENSG00000160293': 14.316666666666672,
#  'ENSG00000107130': 14.3,
#  'ENSG00000170004': 14.283333333333337,
#  'ENSG00000067369': 14.283333333333335,
#  'ENSG00000117899': 14.250000000000002,
#  'ENSG00000139197': 14.233333333333334,
#  'ENSG00000197102': 14.200000000000005,
#  'ENSG00000229809': 14.200000000000001,
#  'ENSG00000169813': 14.166666666666671,
#  'ENSG00000072062': 14.166666666666671,
#  'ENSG00000005102': 14.166666666666671,
#  'ENSG00000137098': 14.16666666666667,
#  'ENSG00000198890': 14.166666666666668,
#  'ENSG00000183137': 14.166666666666668,
#  'ENSG00000186868': 14.116666666666669,
#  'ENSG00000114019': 14.116666666666669,
#  'ENSG00000140941': 14.083333333333336,
#  'ENSG00000112237': 14.083333333333336,
#  'ENSG00000156735': 14.083333333333336,
#  'ENSG00000039068': 14.033333333333339,
#  'ENSG00000073584': 14.033333333333335,
#  'ENSG00000008018': 14.033333333333335,
#  'ENSG00000105894': 14.000000000000004,
#  'ENSG00000033800': 14.000000000000004,
#  'ENSG00000114062': 14.000000000000004,
#  'ENSG00000094880': 14.000000000000002,
#  'ENSG00000171552': 13.950000000000005,
#  'ENSG00000196150': 13.950000000000003,
#  'ENSG00000126581': 13.950000000000003,
#  'ENSG00000106462': 13.91666666666667,
#  'ENSG00000197860': 13.91666666666667,
#  'ENSG00000147144': 13.916666666666668,
#  'ENSG00000125835': 13.900000000000004,
#  'ENSG00000167987': 13.900000000000002,
#  'ENSG00000139531': 13.9,
#  'ENSG00000141551': 13.86666666666667,
#  'ENSG00000074319': 13.866666666666669,
#  'ENSG00000149269': 13.866666666666669,
#  'ENSG00000105392': 13.866666666666669,
#  'ENSG00000175390': 13.83333333333334,
#  'ENSG00000163938': 13.833333333333337,
#  'ENSG00000076604': 13.833333333333337,
#  'ENSG00000175513': 13.833333333333337,
#  'ENSG00000183598': 13.833333333333336,
#  'ENSG00000104852': 13.833333333333334,
#  'ENSG00000132522': 13.816666666666672,
#  'ENSG00000087206': 13.816666666666668,
#  'ENSG00000119689': 13.783333333333339,
#  'ENSG00000140575': 13.783333333333339,
#  'ENSG00000037965': 13.783333333333337,
#  'ENSG00000178209': 13.783333333333337,
#  'ENSG00000112130': 13.783333333333335,
#  'ENSG00000135249': 13.783333333333335,
#  'ENSG00000111640': 13.750000000000007,
#  'ENSG00000106305': 13.750000000000004,
#  'ENSG00000104419': 13.750000000000004,
#  'ENSG00000169045': 13.750000000000004,
#  'ENSG00000101255': 13.750000000000002,
#  'ENSG00000105993': 13.750000000000002,
#  'ENSG00000107643': 13.750000000000002,
#  'ENSG00000161203': 13.750000000000002,
#  'ENSG00000129351': 13.750000000000002,
#  'ENSG00000160753': 13.733333333333338,
#  'ENSG00000151914': 13.700000000000003,
#  'ENSG00000163060': 13.700000000000003,
#  'ENSG00000121058': 13.700000000000003,
#  'ENSG00000088888': 13.700000000000003,
#  'ENSG00000128731': 13.683333333333337,
#  'ENSG00000109103': 13.666666666666671,
#  'ENSG00000103043': 13.666666666666671,
#  'ENSG00000135604': 13.66666666666667,
#  'ENSG00000177889': 13.66666666666667,
#  'ENSG00000142168': 13.66666666666667,
#  'ENSG00000123143': 13.66666666666667,
#  'ENSG00000084652': 13.66666666666667,
#  'ENSG00000115053': 13.666666666666666,
#  'ENSG00000167522': 13.650000000000004,
#  'ENSG00000165527': 13.650000000000004,
#  'ENSG00000197114': 13.650000000000002,
#  'ENSG00000132604': 13.650000000000002,
#  'ENSG00000080815': 13.61666666666667,
#  'ENSG00000171425': 13.61666666666667,
#  'ENSG00000113580': 13.61666666666667,
#  'ENSG00000140961': 13.61666666666667,
#  'ENSG00000070756': 13.61666666666667,
#  'ENSG00000152404': 13.616666666666669,
#  'ENSG00000186575': 13.616666666666669,
#  'ENSG00000184033': 13.616666666666669,
#  'ENSG00000142698': 13.616666666666667,
#  'ENSG00000196781': 13.58333333333334,
#  'ENSG00000138279': 13.58333333333334,
#  'ENSG00000169057': 13.583333333333337,
#  'ENSG00000163602': 13.583333333333337,
#  'ENSG00000138376': 13.583333333333337,
#  'ENSG00000178127': 13.583333333333336,
#  'ENSG00000205726': 13.583333333333336,
#  'ENSG00000204209': 13.583333333333336,
#  'ENSG00000123358': 13.583333333333336,
#  'ENSG00000010017': 13.583333333333336,
#  'ENSG00000166407': 13.583333333333336,
#  'ENSG00000136603': 13.583333333333336,
#  'ENSG00000134107': 13.583333333333334,
#  'ENSG00000126016': 13.583333333333334,
#  'ENSG00000196923': 13.566666666666672,
#  'ENSG00000196391': 13.56666666666667,
#  'ENSG00000148400': 13.566666666666668,
#  'ENSG00000173421': 13.566666666666668,
#  'ENSG00000088808': 13.566666666666668,
#  'ENSG00000188493': 13.533333333333339,
#  'ENSG00000183640': 13.533333333333339,
#  'ENSG00000122565': 13.533333333333337,
#  'ENSG00000112214': 13.533333333333337,
#  'ENSG00000151650': 13.533333333333337,
#  'ENSG00000147548': 13.533333333333337,
#  'ENSG00000134640': 13.533333333333335,
#  'ENSG00000167552': 13.533333333333335,
#  'ENSG00000157212': 13.533333333333335,
#  'ENSG00000221829': 13.533333333333333,
#  'ENSG00000179218': 13.500000000000005,
#  'ENSG00000133935': 13.500000000000004,
#  'ENSG00000198400': 13.483333333333336,
#  'ENSG00000105568': 13.483333333333336,
#  'ENSG00000169071': 13.483333333333336,
#  'ENSG00000141968': 13.483333333333336,
#  'ENSG00000066185': 13.483333333333334,
#  'ENSG00000155657': 13.450000000000005,
#  'ENSG00000196262': 13.450000000000005,
#  'ENSG00000124562': 13.450000000000005,
#  'ENSG00000136827': 13.450000000000005,
#  'ENSG00000171444': 13.450000000000003,
#  'ENSG00000164885': 13.450000000000003,
#  'ENSG00000155313': 13.450000000000003,
#  'ENSG00000132964': 13.450000000000003,
#  'ENSG00000177842': 13.450000000000003,
#  'ENSG00000159251': 13.450000000000003,
#  'ENSG00000144566': 13.450000000000003,
#  'ENSG00000160299': 13.450000000000001,
#  'ENSG00000162521': 13.450000000000001,
#  'ENSG00000121067': 13.450000000000001,
#  'ENSG00000117625': 13.450000000000001,
#  'ENSG00000119703': 13.450000000000001,
#  'ENSG00000130638': 13.433333333333335,
#  'ENSG00000213585': 13.433333333333335,
#  'ENSG00000175455': 13.433333333333334,
#  'ENSG00000108854': 13.416666666666673,
#  'ENSG00000185787': 13.416666666666671,
#  'ENSG00000160202': 13.41666666666667,
#  'ENSG00000141570': 13.41666666666667,
#  'ENSG00000102882': 13.41666666666667,
#  'ENSG00000096401': 13.41666666666667,
#  'ENSG00000143553': 13.41666666666667,
#  'ENSG00000126457': 13.41666666666667,
#  'ENSG00000159216': 13.41666666666667,
#  'ENSG00000127616': 13.416666666666668,
#  'ENSG00000175029': 13.416666666666668,
#  'ENSG00000113522': 13.400000000000002,
#  'ENSG00000136936': 13.400000000000002,
#  'ENSG00000158290': 13.4,
#  'ENSG00000129691': 13.399999999999999,
#  'ENSG00000081386': 13.366666666666672,
#  'ENSG00000180370': 13.36666666666667,
#  'ENSG00000167604': 13.36666666666667,
#  'ENSG00000158169': 13.36666666666667,
#  'ENSG00000130203': 13.36666666666667,
#  'ENSG00000159377': 13.36666666666667,
#  'ENSG00000076382': 13.36666666666667,
#  'ENSG00000108256': 13.36666666666667,
#  'ENSG00000105329': 13.36666666666667,
#  'ENSG00000102081': 13.366666666666669,
#  'ENSG00000166579': 13.366666666666669,
#  'ENSG00000196396': 13.366666666666669,
#  'ENSG00000067560': 13.366666666666669,
#  'ENSG00000118260': 13.366666666666667,
#  'ENSG00000136878': 13.366666666666667,
#  'ENSG00000061455': 13.366666666666667,
#  'ENSG00000115306': 13.350000000000001,
#  'ENSG00000124181': 13.33333333333334,
#  'ENSG00000175899': 13.33333333333334,
#  'ENSG00000179262': 13.333333333333337,
#  'ENSG00000197694': 13.333333333333337,
#  'ENSG00000128534': 13.333333333333337,
#  'ENSG00000164466': 13.333333333333337,
#  'ENSG00000013364': 13.333333333333337,
#  'ENSG00000110367': 13.333333333333337,
#  'ENSG00000064999': 13.333333333333336,
#  'ENSG00000151332': 13.333333333333336,
#  'ENSG00000087586': 13.333333333333336,
#  'ENSG00000101624': 13.333333333333336,
#  'ENSG00000140481': 13.333333333333336,
#  'ENSG00000067066': 13.333333333333334,
#  'ENSG00000186628': 13.333333333333334,
#  'ENSG00000161509': 13.333333333333334,
#  'ENSG00000140464': 13.333333333333334,
#  'ENSG00000139517': 13.333333333333334,
#  'ENSG00000123415': 13.316666666666672,
#  'ENSG00000240682': 13.31666666666667,
#  'ENSG00000140395': 13.31666666666667,
#  'ENSG00000135457': 13.31666666666667,
#  'ENSG00000152240': 13.316666666666668,
#  'ENSG00000131931': 13.316666666666668,
#  'ENSG00000078043': 13.316666666666668,
#  'ENSG00000100567': 13.283333333333339,
#  'ENSG00000254772': 13.283333333333339,
#  'ENSG00000127993': 13.283333333333337,
#  'ENSG00000137218': 13.283333333333337,
#  'ENSG00000096717': 13.283333333333337,
#  'ENSG00000135486': 13.283333333333337,
#  'ENSG00000188486': 13.283333333333337,
#  'ENSG00000172349': 13.283333333333337,
#  'ENSG00000145901': 13.283333333333337,
#  'ENSG00000180530': 13.283333333333337,
#  'ENSG00000079277': 13.283333333333335,
#  'ENSG00000105617': 13.283333333333335,
#  'ENSG00000128596': 13.283333333333335,
#  'ENSG00000150093': 13.283333333333335,
#  'ENSG00000100387': 13.283333333333335,
#  'ENSG00000154359': 13.283333333333335,
#  'ENSG00000166925': 13.283333333333335,
#  'ENSG00000158246': 13.283333333333335,
#  'ENSG00000105717': 13.250000000000005,
#  'ENSG00000099783': 13.250000000000005,
#  'ENSG00000136158': 13.250000000000005,
#  'ENSG00000072958': 13.250000000000005,
#  'ENSG00000145982': 13.250000000000004,
#  'ENSG00000163879': 13.250000000000004,
#  'ENSG00000140299': 13.250000000000004,
#  'ENSG00000127980': 13.250000000000004,
#  'ENSG00000116044': 13.250000000000004,
#  'ENSG00000183765': 13.250000000000004,
#  'ENSG00000166946': 13.250000000000004,
#  'ENSG00000100065': 13.250000000000002,
#  'ENSG00000126603': 13.250000000000002,
#  'ENSG00000116455': 13.250000000000002,
#  'ENSG00000182195': 13.250000000000002,
#  'ENSG00000261371': 13.250000000000002,
#  'ENSG00000105404': 13.250000000000002,
#  'ENSG00000185247': 13.250000000000002,
#  'ENSG00000150773': 13.25,
#  'ENSG00000110777': 13.233333333333338,
#  'ENSG00000155329': 13.233333333333338,
#  'ENSG00000148737': 13.233333333333336,
#  'ENSG00000138180': 13.233333333333336,
#  'ENSG00000145907': 13.233333333333336,
#  'ENSG00000127947': 13.233333333333336,
#  'ENSG00000147596': 13.233333333333336,
#  'ENSG00000109685': 13.233333333333334,
#  'ENSG00000154277': 13.233333333333333,
#  'ENSG00000198919': 13.216666666666669,
#  'ENSG00000127054': 13.200000000000005,
#  'ENSG00000092330': 13.200000000000005,
#  'ENSG00000005007': 13.200000000000005,
#  'ENSG00000140368': 13.200000000000003,
#  'ENSG00000165140': 13.200000000000003,
#  'ENSG00000076321': 13.200000000000003,
#  'ENSG00000136754': 13.200000000000003,
#  'ENSG00000105974': 13.200000000000003,
#  'ENSG00000115317': 13.200000000000003,
#  'ENSG00000183230': 13.200000000000003,
#  'ENSG00000167770': 13.200000000000003,
#  'ENSG00000100351': 13.200000000000003,
#  'ENSG00000079999': 13.200000000000001,
#  'ENSG00000169564': 13.200000000000001,
#  'ENSG00000055130': 13.200000000000001,
#  'ENSG00000185963': 13.200000000000001,
#  'ENSG00000161992': 13.200000000000001,
#  'ENSG00000143156': 13.183333333333337,
#  'ENSG00000140382': 13.183333333333335,
#  'ENSG00000077942': 13.183333333333335,
#  'ENSG00000150457': 13.183333333333335,
#  'ENSG00000142655': 13.183333333333335,
#  'ENSG00000094631': 13.166666666666671,
#  'ENSG00000137693': 13.166666666666671,
#  'ENSG00000198742': 13.166666666666671,
#  'ENSG00000148175': 13.166666666666671,
#  'ENSG00000135250': 13.166666666666671,
#  'ENSG00000125844': 13.166666666666671,
#  'ENSG00000101856': 13.16666666666667,
#  'ENSG00000172053': 13.16666666666667,
#  'ENSG00000133243': 13.16666666666667,
#  'ENSG00000179562': 13.16666666666667,
#  'ENSG00000165626': 13.16666666666667,
#  'ENSG00000135316': 13.16666666666667,
#  'ENSG00000117505': 13.166666666666668,
#  'ENSG00000182481': 13.166666666666668,
#  'ENSG00000186350': 13.166666666666668,
#  'ENSG00000137947': 13.166666666666668,
#  'ENSG00000138101': 13.166666666666668,
#  'ENSG00000127914': 13.166666666666668,
#  'ENSG00000164440': 13.166666666666668,
#  'ENSG00000089280': 13.166666666666668,
#  'ENSG00000119041': 13.166666666666668,
#  'ENSG00000141376': 13.166666666666666,
#  'ENSG00000182591': 13.150000000000004,
#  'ENSG00000172466': 13.150000000000004,
#  'ENSG00000138750': 13.150000000000004,
#  'ENSG00000110395': 13.150000000000004,
#  'ENSG00000159692': 13.150000000000004,
#  'ENSG00000158560': 13.150000000000004,
#  'ENSG00000171953': 13.150000000000002,
#  'ENSG00000109089': 13.150000000000002,
#  'ENSG00000196230': 13.150000000000002,
#  'ENSG00000089159': 13.150000000000002,
#  'ENSG00000197299': 13.150000000000002,
#  'ENSG00000272514': 13.15,
#  'ENSG00000155959': 13.133333333333338,
#  'ENSG00000166037': 13.133333333333335,
#  'ENSG00000204438': 13.116666666666672,
#  'ENSG00000165025': 13.11666666666667,
#  'ENSG00000156976': 13.11666666666667,
#  'ENSG00000188906': 13.11666666666667,
#  'ENSG00000196092': 13.11666666666667,
#  'ENSG00000105976': 13.11666666666667,
#  'ENSG00000136925': 13.11666666666667,
#  'ENSG00000185624': 13.11666666666667,
#  'ENSG00000152291': 13.11666666666667,
#  'ENSG00000072501': 13.116666666666669,
#  'ENSG00000135655': 13.116666666666669,
#  'ENSG00000213639': 13.116666666666669,
#  'ENSG00000141837': 13.116666666666669,
#  'ENSG00000113916': 13.116666666666669,
#  'ENSG00000114742': 13.116666666666669,
#  'ENSG00000163631': 13.116666666666669,
#  'ENSG00000170345': 13.116666666666669,
#  'ENSG00000138795': 13.116666666666669,
#  'ENSG00000149380': 13.116666666666669,
#  'ENSG00000198668': 13.116666666666669,
#  'ENSG00000144579': 13.116666666666669,
#  'ENSG00000137073': 13.116666666666669,
#  'ENSG00000103528': 13.116666666666669,
#  'ENSG00000170677': 13.116666666666669,
#  'ENSG00000020922': 13.116666666666669,
#  'ENSG00000143952': 13.116666666666667,
#  'ENSG00000116288': 13.116666666666667,
#  'ENSG00000111196': 13.116666666666667,
#  'ENSG00000188612': 13.100000000000003,
#  'ENSG00000078900': 13.100000000000003,
#  'ENSG00000150477': 13.100000000000001,
#  'ENSG00000072832': 13.083333333333337,
#  'ENSG00000142686': 13.083333333333337,
#  'ENSG00000100462': 13.083333333333337,
#  'ENSG00000108010': 13.083333333333337,
#  'ENSG00000109670': 13.083333333333336,
#  'ENSG00000078246': 13.083333333333336,
#  'ENSG00000047932': 13.083333333333336,
#  'ENSG00000254999': 13.083333333333336,
#  'ENSG00000131721': 13.083333333333336,
#  'ENSG00000188191': 13.083333333333336,
#  'ENSG00000151929': 13.083333333333336,
#  'ENSG00000121774': 13.083333333333334,
#  'ENSG00000167005': 13.066666666666672,
#  'ENSG00000198492': 13.06666666666667,
#  'ENSG00000100354': 13.06666666666667,
#  'ENSG00000175166': 13.06666666666667,
#  'ENSG00000184009': 13.06666666666667,
#  'ENSG00000113658': 13.06666666666667,
#  'ENSG00000171862': 13.06666666666667,
#  'ENSG00000165156': 13.066666666666668,
#  'ENSG00000008294': 13.066666666666668,
#  'ENSG00000175054': 13.066666666666666,
#  'ENSG00000080986': 13.066666666666666,
#  'ENSG00000164053': 13.05,
#  'ENSG00000088832': 13.033333333333339,
#  'ENSG00000140443': 13.033333333333337,
#  'ENSG00000162881': 13.033333333333337,
#  'ENSG00000215193': 13.033333333333337,
#  'ENSG00000108671': 13.033333333333337,
#  'ENSG00000071539': 13.033333333333337,
#  'ENSG00000197079': 13.033333333333337,
#  'ENSG00000254087': 13.033333333333337,
#  'ENSG00000124216': 13.033333333333337,
#  'ENSG00000115966': 13.033333333333337,
#  'ENSG00000113721': 13.033333333333337,
#  'ENSG00000182866': 13.033333333333337,
#  'ENSG00000096093': 13.033333333333335,
#  'ENSG00000164438': 13.033333333333335,
#  'ENSG00000009790': 13.033333333333335,
#  'ENSG00000137337': 13.033333333333335,
#  'ENSG00000085224': 13.033333333333335,
#  'ENSG00000188554': 13.033333333333335,
#  'ENSG00000090520': 13.033333333333335,
#  'ENSG00000117450': 13.033333333333335,
#  'ENSG00000104812': 13.033333333333335,
#  'ENSG00000127946': 13.033333333333333,
#  'ENSG00000253729': 13.033333333333333,
#  'ENSG00000108395': 13.033333333333333,
#  'ENSG00000264364': 13.016666666666671,
#  'ENSG00000162526': 13.016666666666671,
#  'ENSG00000160062': 13.01666666666667,
#  'ENSG00000179010': 13.01666666666667,
#  'ENSG00000184708': 13.01666666666667,
#  'ENSG00000119772': 13.016666666666667,
#  'ENSG00000167565': 13.016666666666667,
#  'ENSG00000149257': 13.000000000000005,
#  'ENSG00000196700': 13.000000000000005,
#  'ENSG00000198945': 13.000000000000004,
#  'ENSG00000101665': 13.000000000000004,
#  'ENSG00000105701': 13.000000000000004,
#  'ENSG00000039650': 13.000000000000004,
#  'ENSG00000069869': 13.000000000000004,
#  'ENSG00000065491': 13.000000000000004,
#  'ENSG00000070808': 13.000000000000004,
#  'ENSG00000120885': 13.000000000000004,
#  'ENSG00000102226': 13.000000000000004,
#  'ENSG00000135446': 13.000000000000004,
#  'ENSG00000204842': 13.000000000000004,
#  'ENSG00000132155': 13.000000000000004,
#  'ENSG00000065029': 13.000000000000004,
#  'ENSG00000197822': 13.000000000000002,
#  'ENSG00000121060': 13.000000000000002,
#  'ENSG00000103415': 13.000000000000002,
#  'ENSG00000050748': 13.000000000000002,
#  'ENSG00000223501': 13.000000000000002,
#  'ENSG00000115415': 13.000000000000002,
#  'ENSG00000164649': 13.000000000000002,
#  'ENSG00000139687': 13.0,
#  'ENSG00000169398': 12.983333333333338,
#  'ENSG00000198561': 12.983333333333338,
#  'ENSG00000151414': 12.983333333333338,
#  'ENSG00000090061': 12.983333333333336,
#  'ENSG00000126337': 12.983333333333336,
#  'ENSG00000108055': 12.983333333333336,
#  'ENSG00000068028': 12.983333333333336,
#  'ENSG00000105325': 12.983333333333336,
#  'ENSG00000162366': 12.983333333333336,
#  'ENSG00000166226': 12.983333333333336,
#  'ENSG00000109083': 12.983333333333336,
#  'ENSG00000023330': 12.983333333333334,
#  'ENSG00000057935': 12.983333333333334,
#  'ENSG00000146963': 12.983333333333334,
#  'ENSG00000133103': 12.983333333333334,
#  'ENSG00000116903': 12.983333333333334,
#  'ENSG00000157450': 12.983333333333334,
#  'ENSG00000123908': 12.983333333333334,
#  'ENSG00000184900': 12.983333333333334,
#  'ENSG00000185379': 12.96666666666667,
#  'ENSG00000102977': 12.950000000000005,
#  'ENSG00000175294': 12.950000000000005,
#  'ENSG00000113068': 12.950000000000005,
#  'ENSG00000104381': 12.950000000000005,
#  'ENSG00000169032': 12.950000000000005,
#  'ENSG00000066136': 12.950000000000005,
#  'ENSG00000141027': 12.950000000000005,
#  'ENSG00000127903': 12.950000000000005,
#  'ENSG00000108829': 12.950000000000005,
#  'ENSG00000078140': 12.950000000000003,
#  'ENSG00000148346': 12.950000000000003,
#  'ENSG00000111057': 12.950000000000003,
#  'ENSG00000196290': 12.950000000000003,
#  'ENSG00000164056': 12.950000000000003,
#  'ENSG00000121057': 12.950000000000003,
#  'ENSG00000242247': 12.950000000000003,
#  'ENSG00000111642': 12.950000000000003,
#  'ENSG00000104064': 12.950000000000003,
#  'ENSG00000104695': 12.950000000000003,
#  'ENSG00000103126': 12.950000000000003,
#  'ENSG00000138448': 12.950000000000003,
#  'ENSG00000119392': 12.950000000000001,
#  'ENSG00000131408': 12.950000000000001,
#  'ENSG00000029725': 12.950000000000001,
#  'ENSG00000068024': 12.950000000000001,
#  'ENSG00000131738': 12.950000000000001,
#  'ENSG00000075785': 12.950000000000001,
#  'ENSG00000165916': 12.95,
#  'ENSG00000154640': 12.95,
#  'ENSG00000166348': 12.933333333333337,
#  'ENSG00000058056': 12.933333333333337,
#  'ENSG00000196363': 12.933333333333335,
#  'ENSG00000151790': 12.933333333333335,
#  'ENSG00000129355': 12.933333333333335,
#  'ENSG00000168301': 12.933333333333335,
#  'ENSG00000172379': 12.933333333333335,
#  'ENSG00000115392': 12.933333333333335,
#  'ENSG00000080345': 12.933333333333335,
#  'ENSG00000162928': 12.933333333333335,
#  'ENSG00000165392': 12.933333333333335,
#  'ENSG00000122952': 12.933333333333334,
#  'ENSG00000203786': 12.916666666666671,
#  'ENSG00000100811': 12.916666666666671,
#  'ENSG00000156697': 12.91666666666667,
#  'ENSG00000183690': 12.91666666666667,
#  'ENSG00000175213': 12.91666666666667,
#  'ENSG00000070748': 12.91666666666667,
#  'ENSG00000182670': 12.916666666666668,
#  'ENSG00000163697': 12.916666666666668,
#  'ENSG00000074266': 12.916666666666666,
#  'ENSG00000121481': 12.900000000000004,
#  'ENSG00000188313': 12.900000000000004,
#  'ENSG00000128052': 12.900000000000004,
#  'ENSG00000170276': 12.900000000000004,
#  'ENSG00000130159': 12.900000000000004,
#  'ENSG00000151379': 12.900000000000004,
#  'ENSG00000109458': 12.900000000000004,
#  'ENSG00000176105': 12.900000000000004,
#  'ENSG00000011590': 12.900000000000004,
#  'ENSG00000105700': 12.900000000000002,
#  'ENSG00000131467': 12.900000000000002,
#  'ENSG00000157404': 12.900000000000002,
#  'ENSG00000106052': 12.900000000000002,
#  'ENSG00000179950': 12.900000000000002,
#  'ENSG00000168118': 12.900000000000002,
#  'ENSG00000171791': 12.900000000000002,
#  'ENSG00000050820': 12.900000000000002,
#  'ENSG00000105323': 12.900000000000002,
#  'ENSG00000122299': 12.900000000000002,
#  'ENSG00000183621': 12.900000000000002,
#  'ENSG00000104756': 12.900000000000002,
#  'ENSG00000142149': 12.9,
#  'ENSG00000149554': 12.9,
#  'ENSG00000115738': 12.9,
#  'ENSG00000169139': 12.9,
#  'ENSG00000113575': 12.9,
#  'ENSG00000140320': 12.86666666666667,
#  'ENSG00000182816': 12.86666666666667,
#  'ENSG00000087338': 12.86666666666667,
#  'ENSG00000109180': 12.86666666666667,
#  'ENSG00000103423': 12.86666666666667,
#  'ENSG00000105647': 12.86666666666667,
#  'ENSG00000128272': 12.86666666666667,
#  'ENSG00000143442': 12.86666666666667,
#  'ENSG00000094916': 12.86666666666667,
#  'ENSG00000132305': 12.86666666666667,
#  'ENSG00000100348': 12.866666666666669,
#  'ENSG00000107404': 12.866666666666669,
#  'ENSG00000131023': 12.866666666666669,
#  'ENSG00000102804': 12.866666666666669,
#  'ENSG00000167615': 12.866666666666669,
#  'ENSG00000104343': 12.866666666666669,
#  'ENSG00000272325': 12.866666666666669,
#  'ENSG00000244687': 12.866666666666669,
#  'ENSG00000132170': 12.866666666666669,
#  'ENSG00000100345': 12.866666666666669,
#  'ENSG00000133134': 12.866666666666669,
#  'ENSG00000171720': 12.866666666666669,
#  'ENSG00000171360': 12.866666666666669,
#  'ENSG00000142864': 12.866666666666669,
#  'ENSG00000196544': 12.866666666666667,
#  'ENSG00000104320': 12.866666666666667,
#  'ENSG00000108309': 12.866666666666667,
#  'ENSG00000197172': 12.866666666666665,
#  'ENSG00000165588': 12.850000000000003,
#  'ENSG00000139737': 12.850000000000003,
#  'ENSG00000153060': 12.850000000000003,
#  'ENSG00000136560': 12.850000000000001,
#  'ENSG00000198910': 12.850000000000001,
#  'ENSG00000083535': 12.850000000000001,
#  'ENSG00000156050': 12.850000000000001,
#  'ENSG00000163961': 12.850000000000001,
#  'ENSG00000134684': 12.850000000000001,
#  'ENSG00000118402': 12.83333333333334,
#  'ENSG00000119725': 12.833333333333337,
#  'ENSG00000154229': 12.833333333333337,
#  'ENSG00000106799': 12.833333333333337,
#  'ENSG00000198925': 12.833333333333337,
#  'ENSG00000185272': 12.833333333333336,
#  'ENSG00000177606': 12.833333333333336,
#  'ENSG00000168646': 12.833333333333336,
#  'ENSG00000171490': 12.833333333333336,
#  'ENSG00000143801': 12.833333333333336,
#  'ENSG00000005486': 12.833333333333336,
#  'ENSG00000185386': 12.833333333333336,
#  'ENSG00000100320': 12.833333333333334,
#  'ENSG00000157500': 12.833333333333334,
#  'ENSG00000101004': 12.833333333333334,
#  'ENSG00000171621': 12.833333333333334,
#  'ENSG00000078902': 12.833333333333332,
#  'ENSG00000174099': 12.816666666666672,
#  'ENSG00000169519': 12.816666666666672,
#  'ENSG00000108590': 12.816666666666672,
#  'ENSG00000092529': 12.81666666666667,
#  'ENSG00000198373': 12.81666666666667,
#  'ENSG00000171345': 12.81666666666667,
#  'ENSG00000204392': 12.81666666666667,
#  'ENSG00000136810': 12.81666666666667,
#  'ENSG00000132792': 12.81666666666667,
#  'ENSG00000135052': 12.81666666666667,
#  'ENSG00000092820': 12.81666666666667,
#  'ENSG00000137648': 12.81666666666667,
#  'ENSG00000152102': 12.81666666666667,
#  'ENSG00000166886': 12.816666666666668,
#  'ENSG00000137309': 12.816666666666668,
#  'ENSG00000168259': 12.816666666666668,
#  'ENSG00000175197': 12.816666666666668,
#  'ENSG00000141644': 12.816666666666668,
#  'ENSG00000113368': 12.816666666666666,
#  'ENSG00000146007': 12.800000000000002,
#  'ENSG00000112357': 12.800000000000002,
#  'ENSG00000164591': 12.800000000000002,
#  'ENSG00000173801': 12.783333333333339,
#  'ENSG00000178568': 12.783333333333339,
#  'ENSG00000134371': 12.783333333333337,
#  'ENSG00000100823': 12.783333333333337,
#  'ENSG00000102145': 12.783333333333337,
#  'ENSG00000173207': 12.783333333333337,
#  'ENSG00000184402': 12.783333333333337,
#  'ENSG00000104388': 12.783333333333337,
#  'ENSG00000165630': 12.783333333333337,
#  'ENSG00000146731': 12.783333333333337,
#  'ENSG00000051128': 12.783333333333337,
#  'ENSG00000178395': 12.783333333333337,
#  'ENSG00000131143': 12.783333333333337,
#  'ENSG00000196498': 12.783333333333335,
#  'ENSG00000178999': 12.783333333333335,
#  'ENSG00000264522': 12.783333333333335,
#  'ENSG00000115540': 12.783333333333335,
#  'ENSG00000100906': 12.783333333333335,
#  'ENSG00000151491': 12.783333333333335,
#  'ENSG00000172354': 12.783333333333335,
#  'ENSG00000017797': 12.783333333333335,
#  'ENSG00000101773': 12.783333333333333,
#  'ENSG00000068400': 12.783333333333333,
#  'ENSG00000108021': 12.783333333333333,
#  'ENSG00000082898': 12.76666666666667,
#  'ENSG00000239672': 12.76666666666667,
#  'ENSG00000079950': 12.76666666666667,
#  'ENSG00000134138': 12.76666666666667,
#  'ENSG00000111276': 12.76666666666667,
#  'ENSG00000156006': 12.766666666666667,
#  'ENSG00000118785': 12.766666666666666,
#  'ENSG00000113790': 12.750000000000005,
#  'ENSG00000067955': 12.750000000000004,
#  'ENSG00000117360': 12.750000000000004,
#  'ENSG00000077522': 12.750000000000004,
#  'ENSG00000178104': 12.750000000000004,
#  'ENSG00000145945': 12.750000000000004,
#  'ENSG00000105723': 12.750000000000004,
#  'ENSG00000134532': 12.750000000000004,
#  'ENSG00000074800': 12.750000000000004,
#  'ENSG00000080503': 12.750000000000004,
#  'ENSG00000066044': 12.750000000000004,
#  'ENSG00000173933': 12.750000000000004,
#  'ENSG00000112511': 12.750000000000002,
#  'ENSG00000118271': 12.750000000000002,
#  'ENSG00000115762': 12.733333333333338,
#  'ENSG00000176125': 12.733333333333338,
#  'ENSG00000140259': 12.733333333333336,
#  'ENSG00000198060': 12.733333333333336,
#  'ENSG00000116752': 12.733333333333336,
#  'ENSG00000120860': 12.733333333333336,
#  'ENSG00000046651': 12.733333333333336,
#  'ENSG00000173805': 12.733333333333336,
#  'ENSG00000103154': 12.733333333333336,
#  'ENSG00000115041': 12.733333333333336,
#  'ENSG00000118579': 12.733333333333336,
#  'ENSG00000151338': 12.733333333333336,
#  'ENSG00000051180': 12.733333333333336,
#  'ENSG00000116717': 12.733333333333336,
#  'ENSG00000136938': 12.733333333333336,
#  'ENSG00000123595': 12.733333333333336,
#  'ENSG00000242372': 12.733333333333334,
#  'ENSG00000175203': 12.733333333333334,
#  'ENSG00000146112': 12.733333333333334,
#  'ENSG00000213658': 12.733333333333334,
#  'ENSG00000115760': 12.733333333333334,
#  'ENSG00000165171': 12.71666666666667,
#  'ENSG00000116285': 12.716666666666669,
#  'ENSG00000185825': 12.700000000000005,
#  'ENSG00000055208': 12.700000000000005,
#  'ENSG00000136874': 12.700000000000005,
#  'ENSG00000099942': 12.700000000000005,
#  'ENSG00000006659': 12.700000000000005,
#  'ENSG00000170509': 12.700000000000005,
#  'ENSG00000111679': 12.700000000000005,
#  'ENSG00000123159': 12.700000000000005,
#  'ENSG00000108375': 12.700000000000003,
#  'ENSG00000101336': 12.700000000000003,
#  'ENSG00000115414': 12.700000000000003,
#  'ENSG00000104856': 12.700000000000003,
#  'ENSG00000069011': 12.700000000000003,
#  'ENSG00000163939': 12.700000000000003,
#  'ENSG00000163930': 12.700000000000003,
#  'ENSG00000011243': 12.700000000000003,
#  'ENSG00000078369': 12.700000000000003,
#  'ENSG00000092199': 12.700000000000003,
#  'ENSG00000061337': 12.700000000000003,
#  'ENSG00000137818': 12.700000000000003,
#  'ENSG00000213024': 12.700000000000003,
#  'ENSG00000138413': 12.700000000000003,
#  'ENSG00000034713': 12.700000000000003,
#  'ENSG00000150636': 12.700000000000003,
#  'ENSG00000139613': 12.700000000000003,
#  'ENSG00000105048': 12.700000000000001,
#  'ENSG00000185880': 12.700000000000001,
#  'ENSG00000135205': 12.700000000000001,
#  'ENSG00000141367': 12.700000000000001,
#  'ENSG00000140262': 12.700000000000001,
#  'ENSG00000135951': 12.700000000000001,
#  'ENSG00000160867': 12.700000000000001,
#  'ENSG00000165702': 12.700000000000001,
#  'ENSG00000065135': 12.700000000000001,
#  'ENSG00000105426': 12.700000000000001,
#  'ENSG00000173991': 12.700000000000001,
#  'ENSG00000090621': 12.700000000000001,
#  'ENSG00000153187': 12.700000000000001,
#  'ENSG00000213654': 12.683333333333339,
#  'ENSG00000099377': 12.683333333333337,
#  'ENSG00000054965': 12.683333333333337,
#  'ENSG00000162148': 12.683333333333337,
#  'ENSG00000095951': 12.683333333333335,
#  'ENSG00000136881': 12.683333333333335,
#  'ENSG00000152977': 12.683333333333335,
#  'ENSG00000198959': 12.683333333333335,
#  'ENSG00000135093': 12.683333333333334,
#  'ENSG00000078114': 12.683333333333334,
#  'ENSG00000164733': 12.666666666666671,
#  'ENSG00000110092': 12.666666666666671,
#  'ENSG00000147421': 12.66666666666667,
#  'ENSG00000144021': 12.66666666666667,
#  'ENSG00000155754': 12.66666666666667,
#  'ENSG00000064012': 12.66666666666667,
#  'ENSG00000071655': 12.666666666666668,
#  'ENSG00000213341': 12.666666666666668,
#  'ENSG00000137936': 12.666666666666668,
#  'ENSG00000184351': 12.650000000000004,
#  'ENSG00000140743': 12.650000000000004,
#  'ENSG00000143368': 12.650000000000004,
#  'ENSG00000162585': 12.650000000000004,
#  'ENSG00000183735': 12.650000000000002,
#  'ENSG00000136861': 12.650000000000002,
#  'ENSG00000113141': 12.650000000000002,
#  'ENSG00000172680': 12.650000000000002,
#  'ENSG00000139546': 12.650000000000002,
#  'ENSG00000162961': 12.650000000000002,
#  'ENSG00000169981': 12.650000000000002,
#  'ENSG00000121931': 12.650000000000002,
#  'ENSG00000132356': 12.650000000000002,
#  'ENSG00000066379': 12.650000000000002,
#  'ENSG00000164609': 12.650000000000002,
#  'ENSG00000174799': 12.650000000000002,
#  'ENSG00000183628': 12.650000000000002,
#  'ENSG00000143033': 12.650000000000002,
#  'ENSG00000143549': 12.650000000000002,
#  'ENSG00000123080': 12.650000000000002,
#  'ENSG00000163395': 12.650000000000002,
#  'ENSG00000151365': 12.650000000000002,
#  'ENSG00000197442': 12.650000000000002,
#  'ENSG00000244607': 12.650000000000002,
#  'ENSG00000204371': 12.650000000000002,
#  'ENSG00000110318': 12.650000000000002,
#  'ENSG00000139714': 12.65,
#  'ENSG00000145715': 12.65,
#  'ENSG00000155827': 12.65,
#  'ENSG00000088727': 12.65,
#  'ENSG00000167670': 12.633333333333336,
#  'ENSG00000099812': 12.633333333333336,
#  'ENSG00000131149': 12.633333333333336,
#  'ENSG00000185728': 12.633333333333335,
#  'ENSG00000108733': 12.633333333333335,
#  'ENSG00000141699': 12.616666666666672,
#  'ENSG00000049759': 12.61666666666667,
#  'ENSG00000212901': 12.61666666666667,
#  'ENSG00000115524': 12.61666666666667,
#  'ENSG00000072110': 12.61666666666667,
#  'ENSG00000130818': 12.61666666666667,
#  'ENSG00000160307': 12.61666666666667,
#  'ENSG00000170819': 12.61666666666667,
#  'ENSG00000174106': 12.61666666666667,
#  'ENSG00000107187': 12.61666666666667,
#  'ENSG00000180900': 12.61666666666667,
#  'ENSG00000163131': 12.616666666666669,
#  'ENSG00000169100': 12.616666666666669,
#  'ENSG00000106299': 12.616666666666669,
#  'ENSG00000123562': 12.616666666666669,
#  'ENSG00000010671': 12.616666666666669,
#  'ENSG00000114166': 12.616666666666669,
#  'ENSG00000113569': 12.616666666666669,
#  'ENSG00000123154': 12.616666666666669,
#  'ENSG00000141013': 12.616666666666669,
#  'ENSG00000118705': 12.616666666666669,
#  'ENSG00000147274': 12.616666666666669,
#  'ENSG00000204351': 12.616666666666669,
#  'ENSG00000155875': 12.616666666666669,
#  'ENSG00000107295': 12.616666666666669,
#  'ENSG00000099817': 12.616666666666669,
#  'ENSG00000189403': 12.616666666666669,
#  'ENSG00000070367': 12.616666666666667,
#  'ENSG00000138668': 12.616666666666667,
#  'ENSG00000087191': 12.616666666666667,
#  'ENSG00000107929': 12.616666666666667,
#  'ENSG00000005238': 12.600000000000005,
#  'ENSG00000100503': 12.600000000000003,
#  'ENSG00000167515': 12.600000000000003,
#  'ENSG00000079246': 12.600000000000003,
#  'ENSG00000137720': 12.600000000000003,
#  'ENSG00000138080': 12.600000000000003,
#  'ENSG00000066926': 12.600000000000003,
#  'ENSG00000168283': 12.600000000000003,
#  'ENSG00000271503': 12.600000000000003,
#  'ENSG00000173726': 12.600000000000003,
#  'ENSG00000113845': 12.600000000000003,
#  'ENSG00000120498': 12.6,
#  'ENSG00000089234': 12.6,
#  'ENSG00000121454': 12.583333333333337,
#  'ENSG00000204469': 12.583333333333337,
#  'ENSG00000159352': 12.583333333333337,
#  'ENSG00000104611': 12.583333333333337,
#  'ENSG00000108946': 12.583333333333337,
#  'ENSG00000135829': 12.583333333333337,
#  'ENSG00000110330': 12.583333333333337,
#  'ENSG00000100395': 12.583333333333337,
#  'ENSG00000100519': 12.583333333333336,
#  'ENSG00000118046': 12.583333333333336,
#  'ENSG00000137497': 12.583333333333336,
#  'ENSG00000278619': 12.583333333333336,
#  'ENSG00000112576': 12.583333333333336,
#  'ENSG00000198883': 12.583333333333336,
#  'ENSG00000147889': 12.583333333333336,
#  'ENSG00000197381': 12.583333333333336,
#  'ENSG00000160182': 12.583333333333334,
#  'ENSG00000155428': 12.583333333333334,
#  'ENSG00000077800': 12.566666666666672,
#  'ENSG00000100038': 12.566666666666672,
#  'ENSG00000077782': 12.56666666666667,
#  'ENSG00000132963': 12.56666666666667,
#  'ENSG00000130066': 12.56666666666667,
#  'ENSG00000089685': 12.56666666666667,
#  'ENSG00000119403': 12.56666666666667,
#  'ENSG00000212899': 12.56666666666667,
#  'ENSG00000158828': 12.56666666666667,
#  'ENSG00000173757': 12.56666666666667,
#  'ENSG00000107164': 12.56666666666667,
#  'ENSG00000131323': 12.56666666666667,
#  'ENSG00000160284': 12.56666666666667,
#  'ENSG00000148498': 12.566666666666668,
#  'ENSG00000188730': 12.566666666666668,
#  'ENSG00000154710': 12.566666666666668,
#  'ENSG00000172175': 12.566666666666668,
#  'ENSG00000197321': 12.566666666666668,
#  'ENSG00000167526': 12.566666666666668,
#  'ENSG00000154556': 12.566666666666668,
#  'ENSG00000114354': 12.566666666666668,
#  'ENSG00000047579': 12.566666666666668,
#  'ENSG00000204388': 12.566666666666668,
#  'ENSG00000169217': 12.566666666666668,
#  'ENSG00000198908': 12.566666666666668,
#  'ENSG00000138757': 12.566666666666668,
#  'ENSG00000166313': 12.566666666666666,
#  'ENSG00000104164': 12.566666666666666,
#  'ENSG00000116918': 12.566666666666666,
#  'ENSG00000132254': 12.566666666666666,
#  'ENSG00000136146': 12.566666666666666,
#  'ENSG00000182318': 12.550000000000002,
#  'ENSG00000114316': 12.533333333333339,
#  'ENSG00000173473': 12.533333333333339,
#  'ENSG00000171772': 12.533333333333337,
#  'ENSG00000160185': 12.533333333333337,
#  'ENSG00000075711': 12.533333333333337,
#  'ENSG00000104228': 12.533333333333337,
#  'ENSG00000134644': 12.533333333333337,
#  'ENSG00000203814': 12.533333333333337,
#  'ENSG00000198830': 12.533333333333337,
#  'ENSG00000130520': 12.533333333333337,
#  'ENSG00000130234': 12.533333333333337,
#  'ENSG00000105576': 12.533333333333337,
#  'ENSG00000196155': 12.533333333333337,
#  'ENSG00000136929': 12.533333333333337,
#  'ENSG00000177479': 12.533333333333337,
#  'ENSG00000108774': 12.533333333333337,
#  'ENSG00000149557': 12.533333333333335,
#  'ENSG00000147140': 12.533333333333335,
#  'ENSG00000165732': 12.533333333333335,
#  'ENSG00000167768': 12.533333333333335,
#  'ENSG00000105639': 12.533333333333335,
#  'ENSG00000049449': 12.533333333333335,
#  'ENSG00000131558': 12.533333333333335,
#  'ENSG00000186951': 12.533333333333335,
#  'ENSG00000120802': 12.533333333333335,
#  'ENSG00000184557': 12.533333333333335,
#  'ENSG00000189067': 12.533333333333335,
#  'ENSG00000079102': 12.533333333333335,
#  'ENSG00000101213': 12.533333333333335,
#  'ENSG00000102753': 12.533333333333335,
#  'ENSG00000122705': 12.533333333333335,
#  'ENSG00000121741': 12.533333333333335,
#  'ENSG00000204217': 12.533333333333335,
#  'ENSG00000272333': 12.533333333333333,
#  'ENSG00000178988': 12.533333333333333,
#  'ENSG00000198369': 12.516666666666671,
#  'ENSG00000179912': 12.516666666666671,
#  'ENSG00000150753': 12.516666666666671,
#  'ENSG00000204227': 12.51666666666667,
#  'ENSG00000138867': 12.51666666666667,
#  'ENSG00000164118': 12.51666666666667,
#  'ENSG00000197943': 12.51666666666667,
#  'ENSG00000152457': 12.51666666666667,
#  'ENSG00000168710': 12.51666666666667,
#  'ENSG00000133895': 12.51666666666667,
#  'ENSG00000162607': 12.51666666666667,
#  'ENSG00000152944': 12.51666666666667,
#  'ENSG00000152467': 12.51666666666667,
#  'ENSG00000106483': 12.516666666666667,
#  'ENSG00000135046': 12.516666666666667,
#  'ENSG00000064309': 12.516666666666667,
#  'ENSG00000032742': 12.516666666666667,
#  'ENSG00000137312': 12.516666666666667,
#  'ENSG00000132570': 12.516666666666667,
#  'ENSG00000198920': 12.516666666666667,
#  'ENSG00000144857': 12.516666666666667,
#  'ENSG00000178966': 12.516666666666666,
#  'ENSG00000102054': 12.516666666666666,
#  'ENSG00000111596': 12.500000000000004,
#  'ENSG00000170035': 12.500000000000004,
#  'ENSG00000163902': 12.500000000000004,
#  'ENSG00000154767': 12.500000000000004,
#  'ENSG00000124813': 12.500000000000004,
#  'ENSG00000169375': 12.500000000000004,
#  'ENSG00000141480': 12.500000000000004,
#  'ENSG00000234289': 12.500000000000002,
#  'ENSG00000171448': 12.500000000000002,
#  'ENSG00000104365': 12.500000000000002,
#  'ENSG00000116017': 12.500000000000002,
#  'ENSG00000204220': 12.500000000000002,
#  'ENSG00000185591': 12.500000000000002,
#  'ENSG00000138095': 12.500000000000002,
#  'ENSG00000130222': 12.500000000000002,
#  'ENSG00000147854': 12.500000000000002,
#  'ENSG00000100784': 12.5,
#  'ENSG00000120699': 12.5,
#  'ENSG00000184937': 12.5,
#  'ENSG00000131828': 12.483333333333338,
#  'ENSG00000141030': 12.483333333333338,
#  'ENSG00000179930': 12.483333333333338,
#  'ENSG00000027869': 12.483333333333338,
#  'ENSG00000101182': 12.483333333333338,
#  'ENSG00000164867': 12.483333333333338,
#  'ENSG00000166794': 12.483333333333336,
#  'ENSG00000142867': 12.483333333333336,
#  'ENSG00000184939': 12.483333333333336,
#  'ENSG00000107581': 12.483333333333336,
#  'ENSG00000167085': 12.483333333333336,
#  'ENSG00000155304': 12.483333333333336,
#  'ENSG00000101076': 12.483333333333336,
#  'ENSG00000114867': 12.483333333333336,
#  'ENSG00000118898': 12.483333333333336,
#  'ENSG00000137824': 12.483333333333336,
#  'ENSG00000165188': 12.483333333333336,
#  'ENSG00000135406': 12.483333333333336,
#  'ENSG00000110107': 12.483333333333336,
#  'ENSG00000104529': 12.483333333333336,
#  'ENSG00000099949': 12.483333333333336,
#  'ENSG00000100290': 12.483333333333336,
#  'ENSG00000141977': 12.483333333333336,
#  'ENSG00000134215': 12.483333333333336,
#  'ENSG00000108654': 12.483333333333336,
#  'ENSG00000117153': 12.483333333333336,
#  'ENSG00000015475': 12.483333333333336,
#  'ENSG00000100227': 12.483333333333336,
#  'ENSG00000121691': 12.483333333333336,
#  'ENSG00000196338': 12.483333333333336,
#  'ENSG00000064218': 12.483333333333336,
#  'ENSG00000103194': 12.483333333333334,
#  'ENSG00000198189': 12.483333333333334,
#  'ENSG00000105287': 12.483333333333334,
#  'ENSG00000131773': 12.483333333333334,
#  'ENSG00000159289': 12.483333333333334,
#  'ENSG00000169756': 12.483333333333334,
#  'ENSG00000111445': 12.483333333333334,
#  'ENSG00000088305': 12.483333333333334,
#  'ENSG00000163499': 12.483333333333334,
#  'ENSG00000066468': 12.483333333333334,
#  'ENSG00000164040': 12.483333333333334,
#  'ENSG00000180938': 12.483333333333334,
#  'ENSG00000077380': 12.483333333333334,
#  'ENSG00000186141': 12.483333333333334,
#  'ENSG00000263528': 12.483333333333334,
#  'ENSG00000170606': 12.483333333333334,
#  'ENSG00000168028': 12.483333333333334,
#  'ENSG00000167625': 12.483333333333334,
#  'ENSG00000170421': 12.483333333333334,
#  'ENSG00000112592': 12.483333333333334,
#  'ENSG00000060688': 12.483333333333334,
#  'ENSG00000101811': 12.483333333333334,
#  'ENSG00000144711': 12.483333333333334,
#  'ENSG00000159023': 12.483333333333334,
#  'ENSG00000070159': 12.46666666666667,
#  'ENSG00000139343': 12.46666666666667,
#  'ENSG00000188229': 12.46666666666667,
#  'ENSG00000106077': 12.46666666666667,
#  'ENSG00000160972': 12.46666666666667,
#  'ENSG00000153250': 12.46666666666667,
#  'ENSG00000079462': 12.46666666666667,
#  'ENSG00000100299': 12.466666666666669,
#  'ENSG00000215187': 12.466666666666669,
#  'ENSG00000041988': 12.466666666666669,
#  'ENSG00000115756': 12.466666666666669,
#  'ENSG00000272886': 12.450000000000006,
#  'ENSG00000105507': 12.450000000000005,
#  'ENSG00000136026': 12.450000000000005,
#  'ENSG00000212900': 12.450000000000005,
#  ...}

# %%
res_hc_sorted.get('ENSG00000166889')
# Out:
# 12.100000000000003

# %%
# plot harmonic centrality distribution
res_hc_list = [v for k, v in res_hc_sorted.items()]
bins = len(set(res_hc_list))
plt.hist(res_hc_list, bins=bins)
plt.ylabel("Count")
plt.xlabel("Harmonic centrality")
plt.title("Harmonic centrality distribution")
# Out:
# Text(0.5, 1.0, 'Harmonic centrality distribution')

# %%
# harmonic centralis vs. node degree
for k, v in res_hc_sorted.items():
    res_hc_sorted[k] = [v, G.degree(k)]

df_hc = pd.DataFrame.from_dict(res_hc_sorted, orient='index', columns=['Harmonic centrality', 'degree'])

# %%
sns.scatterplot(data=df_hc, x='degree', y='Harmonic centrality')
# Out:
# <Axes: xlabel='degree', ylabel='Harmonic centrality'>

# %% [markdown]
# ### Score 3: Eigenvector centrality

# %%
# The same as in MMAF, because no candidate genes are taken into account
